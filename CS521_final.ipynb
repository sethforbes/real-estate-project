# %%
class calculator(): 
  def __init__(self, new_user, rent, one_percent, price, yearly_rental_income): 
    self.__new_user = new_user #private self attribute
    self.rent = rent #public self attribute
    self.one_percent = one_percent #public self attribute
    self.price = price #public self attribute
    self.__yearly_rental_income = yearly_rental_income

    while True: 
      assert float(rent) >= float(one_percent) #assert statement
      if float(rent) >= float(one_percent):
          print("")
          print("The investment meets the 1% rule. This could be a good investment decision. Now let's calculate the Gross Rent Multiplier. ")
          self.__yearly_rental_income = float(rent) * 12 
          """calculating yearly rental income"""
          self.GRM = float(price)/float(self.__yearly_rental_income) #public attribute
          print("")
          print("GRM: Making " + "$" + str('%.2f' % self.__yearly_rental_income) + " per year from rental income, it will take approximately " + str('%.2f' % self.GRM) + " years to pay off the property.")
          print("-----------------------------------------------------------------------------------")
          print("")
          print("Now that we've determined this to be a good investment, let's assess your rate of return.")
          print("")
          calculator.taxes(taxrate, maintenance_cost, net_operating, cap_rate)
          break

      elif float(rent) < one_percent:
              print("")
              print("The investment does not meet the 1% rule, so you should pass on this or make a lower offer. ")
              break

  def taxes(taxrate, maintenance_cost, net_operating, cap_rate): 
    while True:
            try:
              taxrate = float(input("1. What is the property tax rate in your area? ").replace('%', ''))
              if float(taxrate) > 2.5 or float(taxrate) < 0:
                tax_assess = input("The tax number you entered seems unusual. Are you sure this is correct? ")
                if tax_assess != "yes":
                  print("Please enter the correct tax rate - typically a number between 0-2.5%.")
                  continue
                else:
                  break
            except ValueError:
              print("Please enter a correct tax rate, without the percentage sign.")

            try:
              maintenance_cost = input("2. What do you expect maintenance costs to be in a year? ").replace('$', '').replace(",", '')
            except ValueError:
              print("Please enter correct maintenance costs.")
              continue

            net_operating = yearly_rental_income - ((float(yearly_rental_income)*float(taxrate)) + (float(maintenance_cost)))
            cap_rate = float(net_operating)/float(price)
            percent_tax = "{:.2%}".format(cap_rate)
            print("3. The cap rate for this property is " + str(percent_tax) + ". Generally, a cap rate between 4-10% is considered good.")
            break

    def __repr__(self): 
      return self.__new_user 
      return self.rent 
      return self.one_percent 
      return self.price 
      return self.__yearly_rental_income 

if __name__ == "__main__":
  yearly_rental_income = 0
  maintenance_cost = 0
  taxrate = 0
  net_operating = 0
  cap_rate = 0
  
  input1 = input("What is your first name? ")

  f = open(input1, "a")
  f.write(input1)

  print("Welcome to the investment calculator,", f.name + "." + " Let's get started.")
  print("")
  f.close()

  new_user = input("1. Are you interested in purchasing a rental property? Please enter 'yes' or 'no'.")

  if new_user.lower() != "yes":
    print("This calculator is for investment purposes. Please come back when you're ready.")
  else:
    while True: #while loop
      try: #try block
        property_list = ['House', 'Apartment', 'Condo'] #container type: list
        for i in range (len(property_list)): #iteration
          property_list[i] = property_list[i].lower()
        printable = repr(property_list)
        type_property = input("2. What type of property are you considering investing? Please type 'House', 'Apartment' or 'Condo'.")
        if type_property.lower() not in printable:
          print("Hmm. The property type you inputted is not in our list. Please try again.")
          continue
        else:
              price = float(input("3. What is the price of this property? (You may use a dollar sign and with/without commas.) ").replace('$', '').replace(",", ''))
              one_percent = float(price)*.01
              break
        if ValueError: #iteration
              print("Please enter a correct price for the property you're looking to purchase.")
              continue
      except ValueError:
          print("Please enter a correct number.")
          continue

    while True: #while loop
      try: #try block
        rent = float(input("4. What is the estimated monthly rent you could earn? ").replace('$', '').replace(",", ''))
        calculator(new_user, rent, one_percent, price, yearly_rental_income)
        break
      except ValueError:
        print("Please enter a correct number for the estimated monthly rent.")
